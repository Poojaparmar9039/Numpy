# %% [markdown]
# Numpy-numerical python

# %%
import numpy as np

# %% [markdown]
# creating array from list

# %%
arr_1d =np.array([1,2,3,4,6,7])
print("1D array is",arr_1d)
# Out:
# 1D arrayis [1 2 3 4 6 7]

# %%
arr_2d=np.array([[1,2,3],[4,6,7]])
print("2d array is",arr_2d)
# Out:
# 2d array is [[1 2 3]
#  [4 6 7]]

# %% [markdown]
# List vs Numpy Array

# %%
py_list=[1,2,3]
print("python muiltiplication is",py_list * 2)
# Out:
# python muiltiplication is [1, 2, 3, 1, 2, 3]

# %%
np_array=np.array([1,2,3])
print("python array ",np_array*2)
# Out:
# python array  [2 4 6]

# %%
import time
start=time.time()
py_list=[i*2 for i in range(10000000)]
print("\n list opeartion time ",time.time()-start)
# Out:
#  list opeartion time  0.7464675903320312

# %%
import time
start=time.time()
np_array=np.arange(10000000)
print("\n numpy opeartion time ",time.time()-start)
# Out:
#  numpy opeartion time  0.011752605438232422

# %% [markdown]
# Creating array from scratch

# %%
zeros=np.zeros((4,2))
print(zeros)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
ones=np.ones((3,3))
print(ones)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
full=np.full((3,3),4)
print(full)
# Out:
# [[4 4 4]
#  [4 4 4]
#  [4 4 4]]
